# %% [markdown]
# #**MobileNetV2**

# %% [markdown]
# ###📥 **Import Libraries**

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# common library
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# tensor computation
from tensorflow.random import set_seed
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import plot_model
from keras.models import Model, load_model
from keras.applications import MobileNetV2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###🔒 **Inisialisasi Bilangan Random**

# %%
def set_random(seed):
  np.random.seed(seed)
  set_seed(seed)

set_random(2022)

# %% [markdown]
# ###🪆 **Data Augmentation**

# %%
# file directory
file_dir = '/content/drive/Shareddrives/Teman Tapi Mining/Satria Data/2022/'
data_dir = 'data/Garbage classification/Garbage classification/'
dir = file_dir + data_dir

# train generator
train = ImageDataGenerator(
    horizontal_flip = True, vertical_flip = True,
    validation_split = 0.1, rescale = 1./255,
    shear_range = 0.1, zoom_range = 0.1,
    width_shift_range = 0.1, height_shift_range = 0.1
    )
train_generator = train.flow_from_directory(
    dir, target_size = (512, 384), batch_size = 32,
    class_mode = 'categorical', subset = 'training'
    )

# test generator
test = ImageDataGenerator(rescale = 1./255, validation_split = 0.1)
test_generator = test.flow_from_directory(
    dir, target_size = (512, 384), batch_size = 32,
    class_mode = 'categorical', subset = 'validation'
    )
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %% [markdown]
# ###🎯 **Modeling**

# %%
pretrained = MobileNetV2(input_shape = (512, 384, 3), include_top = False, weights = 'imagenet')
pretrained.trainable = False
layers = Flatten()(pretrained.output)
layers = Dense(64, activation = 'relu')(layers)
outputs = Dense(6, activation = 'softmax')(layers)
model = Model(inputs = [pretrained.input], outputs = [outputs])

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 384, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 256, 192, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 256, 192, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 256, 192, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 256, 192, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 256, 192, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 256, 192, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 256, 192, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 256, 192, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 256, 192, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 256, 192, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 256, 192, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 257, 193, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 128, 96, 96)  864        ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 128, 96, 96)  384        ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 128, 96, 96)  0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 128, 96, 24)  2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 128, 96, 24)  96         ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 128, 96, 144  3456        ['block_1_project_BN[0][0]']
#                                 )
#
#  block_2_expand_BN (BatchNormal  (None, 128, 96, 144  576        ['block_2_expand[0][0]']
#  ization)                       )
#
#  block_2_expand_relu (ReLU)     (None, 128, 96, 144  0           ['block_2_expand_BN[0][0]']
#                                 )
#
#  block_2_depthwise (DepthwiseCo  (None, 128, 96, 144  1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          )
#
#  block_2_depthwise_BN (BatchNor  (None, 128, 96, 144  576        ['block_2_depthwise[0][0]']
#  malization)                    )
#
#  block_2_depthwise_relu (ReLU)  (None, 128, 96, 144  0           ['block_2_depthwise_BN[0][0]']
#                                 )
#
#  block_2_project (Conv2D)       (None, 128, 96, 24)  3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 128, 96, 24)  96         ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 128, 96, 24)  0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 128, 96, 144  3456        ['block_2_add[0][0]']
#                                 )
#
#  block_3_expand_BN (BatchNormal  (None, 128, 96, 144  576        ['block_3_expand[0][0]']
#  ization)                       )
#
#  block_3_expand_relu (ReLU)     (None, 128, 96, 144  0           ['block_3_expand_BN[0][0]']
#                                 )
#
#  block_3_pad (ZeroPadding2D)    (None, 129, 97, 144  0           ['block_3_expand_relu[0][0]']
#                                 )
#
#  block_3_depthwise (DepthwiseCo  (None, 64, 48, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 64, 48, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 64, 48, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 64, 48, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 64, 48, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 64, 48, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 64, 48, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 64, 48, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 64, 48, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 64, 48, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 64, 48, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 64, 48, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 64, 48, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 64, 48, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 64, 48, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 64, 48, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 64, 48, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 64, 48, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 64, 48, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 64, 48, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 64, 48, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 64, 48, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 64, 48, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 64, 48, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 64, 48, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 64, 48, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 65, 49, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 32, 24, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 32, 24, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 32, 24, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 32, 24, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 32, 24, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 32, 24, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 32, 24, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 32, 24, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 32, 24, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 32, 24, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 32, 24, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 32, 24, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 32, 24, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 32, 24, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 32, 24, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 32, 24, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 32, 24, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 32, 24, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 32, 24, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 32, 24, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 32, 24, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 32, 24, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 32, 24, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 32, 24, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 32, 24, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 32, 24, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 32, 24, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 32, 24, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 32, 24, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 32, 24, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 32, 24, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 32, 24, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 32, 24, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 32, 24, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 32, 24, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 32, 24, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 32, 24, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 32, 24, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 32, 24, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 32, 24, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 32, 24, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 32, 24, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 32, 24, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 32, 24, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 32, 24, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 32, 24, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 32, 24, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 32, 24, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 32, 24, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 32, 24, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 32, 24, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 32, 24, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 32, 24, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 32, 24, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 32, 24, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 32, 24, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 32, 24, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 32, 24, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 32, 24, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 32, 24, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 32, 24, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 33, 25, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 16, 12, 576)  5184       ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 16, 12, 576)  2304       ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 16, 12, 576)  0          ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 16, 12, 160)  92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 16, 12, 160)  640        ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 16, 12, 960)  153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 16, 12, 960)  3840       ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 16, 12, 960)  0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 16, 12, 960)  8640       ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 16, 12, 960)  3840       ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 16, 12, 960)  0          ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 16, 12, 160)  153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 16, 12, 160)  640        ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 16, 12, 160)  0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 16, 12, 960)  153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 16, 12, 960)  3840       ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 16, 12, 960)  0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 16, 12, 960)  8640       ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 16, 12, 960)  3840       ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 16, 12, 960)  0          ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 16, 12, 160)  153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 16, 12, 160)  640        ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 16, 12, 160)  0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 16, 12, 960)  153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 16, 12, 960)  3840       ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 16, 12, 960)  0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 16, 12, 960)  8640       ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 16, 12, 960)  3840       ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 16, 12, 960)  0          ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 16, 12, 320)  307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 16, 12, 320)  1280       ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 16, 12, 1280  409600      ['block_16_project_BN[0][0]']
#                                 )
#
#  Conv_1_bn (BatchNormalization)  (None, 16, 12, 1280  5120       ['Conv_1[0][0]']
#                                 )
#
#  out_relu (ReLU)                (None, 16, 12, 1280  0           ['Conv_1_bn[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 245760)       0           ['out_relu[0][0]']
#
#  dense (Dense)                  (None, 64)           15728704    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 6)            390         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 17,987,078
# Trainable params: 15,729,094
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes = True)

# %%
# define parameters
batch_size = 32
num_epochs = 100

# train & test steps
step_size_train = train_generator.n//train_generator.batch_size
step_size_test = test_generator.n//test_generator.batch_size

# %%
history = model.fit(
    train_generator, epochs = num_epochs, steps_per_epoch = step_size_train,
    validation_data = test_generator, validation_steps = step_size_test
    )
# Out:
# Epoch 1/100
# 71/71 [==============================] - 800s 11s/step - loss: 3.1602 - accuracy: 0.5588 - val_loss: 1.1685 - val_accuracy: 0.5804
# Epoch 2/100
# 71/71 [==============================] - 92s 1s/step - loss: 1.0704 - accuracy: 0.6404 - val_loss: 1.1506 - val_accuracy: 0.6071
# Epoch 3/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.9905 - accuracy: 0.6462 - val_loss: 1.0669 - val_accuracy: 0.6875
# Epoch 4/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.9588 - accuracy: 0.6988 - val_loss: 1.0712 - val_accuracy: 0.6339
# Epoch 5/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.8169 - accuracy: 0.7317 - val_loss: 0.8632 - val_accuracy: 0.6741
# Epoch 6/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.6502 - accuracy: 0.7732 - val_loss: 0.7823 - val_accuracy: 0.7500
# Epoch 7/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.6365 - accuracy: 0.7799 - val_loss: 0.9304 - val_accuracy: 0.7366
# Epoch 8/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.5690 - accuracy: 0.8111 - val_loss: 0.9178 - val_accuracy: 0.7054
# Epoch 9/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.4903 - accuracy: 0.8342 - val_loss: 0.7375 - val_accuracy: 0.7411
# Epoch 10/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.5165 - accuracy: 0.8182 - val_loss: 0.8197 - val_accuracy: 0.7277
# Epoch 11/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.4789 - accuracy: 0.8351 - val_loss: 0.7613 - val_accuracy: 0.7411
# Epoch 12/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.4448 - accuracy: 0.8431 - val_loss: 0.8093 - val_accuracy: 0.7634
# Epoch 13/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.3726 - accuracy: 0.8676 - val_loss: 0.8714 - val_accuracy: 0.7455
# Epoch 14/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.3143 - accuracy: 0.8841 - val_loss: 0.8672 - val_accuracy: 0.7366
# Epoch 15/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.3228 - accuracy: 0.8886 - val_loss: 0.8288 - val_accuracy: 0.7857
# Epoch 16/100
# 71/71 [==============================] - 93s 1s/step - loss: 0.3198 - accuracy: 0.8850 - val_loss: 0.8340 - val_accuracy: 0.7589
# Epoch 17/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2931 - accuracy: 0.8997 - val_loss: 0.7975 - val_accuracy: 0.7768
# Epoch 18/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.2765 - accuracy: 0.9055 - val_loss: 0.9280 - val_accuracy: 0.7723
# Epoch 19/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2812 - accuracy: 0.9042 - val_loss: 0.6461 - val_accuracy: 0.7723
# Epoch 20/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.2565 - accuracy: 0.8975 - val_loss: 0.8377 - val_accuracy: 0.7768
# Epoch 21/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2427 - accuracy: 0.9122 - val_loss: 0.7759 - val_accuracy: 0.8170
# Epoch 22/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.2559 - accuracy: 0.9229 - val_loss: 1.1018 - val_accuracy: 0.7946
# Epoch 23/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2393 - accuracy: 0.9144 - val_loss: 0.8349 - val_accuracy: 0.8080
# Epoch 24/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.2402 - accuracy: 0.9167 - val_loss: 0.8603 - val_accuracy: 0.7723
# Epoch 25/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.2301 - accuracy: 0.9238 - val_loss: 0.7613 - val_accuracy: 0.8036
# Epoch 26/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2279 - accuracy: 0.9260 - val_loss: 0.7729 - val_accuracy: 0.7723
# Epoch 27/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.2474 - accuracy: 0.9167 - val_loss: 0.7366 - val_accuracy: 0.7768
# Epoch 28/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2112 - accuracy: 0.9238 - val_loss: 0.6940 - val_accuracy: 0.7946
# Epoch 29/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1818 - accuracy: 0.9291 - val_loss: 0.8071 - val_accuracy: 0.8170
# Epoch 30/100
# 71/71 [==============================] - 89s 1s/step - loss: 0.1891 - accuracy: 0.9349 - val_loss: 0.8742 - val_accuracy: 0.8214
# Epoch 31/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.2000 - accuracy: 0.9300 - val_loss: 0.7626 - val_accuracy: 0.8125
# Epoch 32/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1869 - accuracy: 0.9376 - val_loss: 0.7678 - val_accuracy: 0.8170
# Epoch 33/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1560 - accuracy: 0.9425 - val_loss: 0.6438 - val_accuracy: 0.8036
# Epoch 34/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.2015 - accuracy: 0.9283 - val_loss: 0.9855 - val_accuracy: 0.7902
# Epoch 35/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.1687 - accuracy: 0.9421 - val_loss: 0.7377 - val_accuracy: 0.8348
# Epoch 36/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1641 - accuracy: 0.9430 - val_loss: 0.8625 - val_accuracy: 0.7991
# Epoch 37/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.1730 - accuracy: 0.9367 - val_loss: 0.8824 - val_accuracy: 0.8125
# Epoch 38/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1794 - accuracy: 0.9363 - val_loss: 0.9717 - val_accuracy: 0.7679
# Epoch 39/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1727 - accuracy: 0.9323 - val_loss: 0.8981 - val_accuracy: 0.7902
# Epoch 40/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.1500 - accuracy: 0.9461 - val_loss: 1.1425 - val_accuracy: 0.7991
# Epoch 41/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.1398 - accuracy: 0.9470 - val_loss: 0.7887 - val_accuracy: 0.7812
# Epoch 42/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1671 - accuracy: 0.9425 - val_loss: 0.8304 - val_accuracy: 0.8036
# Epoch 43/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.1502 - accuracy: 0.9425 - val_loss: 0.8895 - val_accuracy: 0.7946
# Epoch 44/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1426 - accuracy: 0.9398 - val_loss: 0.7624 - val_accuracy: 0.8170
# Epoch 45/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1911 - accuracy: 0.9296 - val_loss: 0.9509 - val_accuracy: 0.7991
# Epoch 46/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1407 - accuracy: 0.9483 - val_loss: 0.8018 - val_accuracy: 0.8036
# Epoch 47/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1477 - accuracy: 0.9425 - val_loss: 0.7373 - val_accuracy: 0.8304
# Epoch 48/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1479 - accuracy: 0.9434 - val_loss: 0.7929 - val_accuracy: 0.8036
# Epoch 49/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.1316 - accuracy: 0.9551 - val_loss: 1.0603 - val_accuracy: 0.7902
# Epoch 50/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1301 - accuracy: 0.9537 - val_loss: 0.8234 - val_accuracy: 0.7902
# Epoch 51/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1190 - accuracy: 0.9537 - val_loss: 0.7274 - val_accuracy: 0.7946
# Epoch 52/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1328 - accuracy: 0.9545 - val_loss: 0.7291 - val_accuracy: 0.8036
# Epoch 53/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1203 - accuracy: 0.9492 - val_loss: 0.5275 - val_accuracy: 0.8527
# Epoch 54/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0998 - accuracy: 0.9599 - val_loss: 0.8213 - val_accuracy: 0.8259
# Epoch 55/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1210 - accuracy: 0.9545 - val_loss: 0.8029 - val_accuracy: 0.8304
# Epoch 56/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1213 - accuracy: 0.9554 - val_loss: 0.8962 - val_accuracy: 0.7946
# Epoch 57/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1228 - accuracy: 0.9554 - val_loss: 0.8375 - val_accuracy: 0.8214
# Epoch 58/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1332 - accuracy: 0.9514 - val_loss: 0.9007 - val_accuracy: 0.8170
# Epoch 59/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1301 - accuracy: 0.9563 - val_loss: 0.9398 - val_accuracy: 0.7991
# Epoch 60/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1344 - accuracy: 0.9563 - val_loss: 1.0292 - val_accuracy: 0.8259
# Epoch 61/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1432 - accuracy: 0.9505 - val_loss: 0.9387 - val_accuracy: 0.8214
# Epoch 62/100
# 71/71 [==============================] - 89s 1s/step - loss: 0.1073 - accuracy: 0.9635 - val_loss: 0.9141 - val_accuracy: 0.7946
# Epoch 63/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1160 - accuracy: 0.9577 - val_loss: 0.8190 - val_accuracy: 0.7946
# Epoch 64/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1023 - accuracy: 0.9652 - val_loss: 0.7964 - val_accuracy: 0.8214
# Epoch 65/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1039 - accuracy: 0.9639 - val_loss: 0.7329 - val_accuracy: 0.8170
# Epoch 66/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1180 - accuracy: 0.9612 - val_loss: 0.9356 - val_accuracy: 0.8080
# Epoch 67/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1200 - accuracy: 0.9563 - val_loss: 0.8649 - val_accuracy: 0.8304
# Epoch 68/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0894 - accuracy: 0.9688 - val_loss: 0.8241 - val_accuracy: 0.8571
# Epoch 69/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1359 - accuracy: 0.9545 - val_loss: 0.7969 - val_accuracy: 0.8393
# Epoch 70/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1151 - accuracy: 0.9617 - val_loss: 0.8401 - val_accuracy: 0.8214
# Epoch 71/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0749 - accuracy: 0.9768 - val_loss: 0.9896 - val_accuracy: 0.8080
# Epoch 72/100
# 71/71 [==============================] - 93s 1s/step - loss: 0.0727 - accuracy: 0.9737 - val_loss: 0.9782 - val_accuracy: 0.8125
# Epoch 73/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0870 - accuracy: 0.9697 - val_loss: 0.8193 - val_accuracy: 0.8214
# Epoch 74/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0888 - accuracy: 0.9679 - val_loss: 0.9689 - val_accuracy: 0.8214
# Epoch 75/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1015 - accuracy: 0.9675 - val_loss: 0.8211 - val_accuracy: 0.8214
# Epoch 76/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1151 - accuracy: 0.9599 - val_loss: 1.1049 - val_accuracy: 0.8080
# Epoch 77/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1039 - accuracy: 0.9661 - val_loss: 1.1771 - val_accuracy: 0.7902
# Epoch 78/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0912 - accuracy: 0.9715 - val_loss: 1.1971 - val_accuracy: 0.7768
# Epoch 79/100
# 71/71 [==============================] - 92s 1s/step - loss: 0.0819 - accuracy: 0.9675 - val_loss: 0.9269 - val_accuracy: 0.8125
# Epoch 80/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0773 - accuracy: 0.9715 - val_loss: 0.7298 - val_accuracy: 0.8170
# Epoch 81/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0749 - accuracy: 0.9724 - val_loss: 0.7742 - val_accuracy: 0.8036
# Epoch 82/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0789 - accuracy: 0.9701 - val_loss: 1.0355 - val_accuracy: 0.8170
# Epoch 83/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0915 - accuracy: 0.9643 - val_loss: 0.8561 - val_accuracy: 0.8214
# Epoch 84/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1075 - accuracy: 0.9652 - val_loss: 0.9784 - val_accuracy: 0.7902
# Epoch 85/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0951 - accuracy: 0.9661 - val_loss: 0.9614 - val_accuracy: 0.8259
# Epoch 86/100
# 71/71 [==============================] - 89s 1s/step - loss: 0.0743 - accuracy: 0.9724 - val_loss: 1.0009 - val_accuracy: 0.8125
# Epoch 87/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0679 - accuracy: 0.9719 - val_loss: 0.9480 - val_accuracy: 0.8304
# Epoch 88/100
# 71/71 [==============================] - 89s 1s/step - loss: 0.1011 - accuracy: 0.9635 - val_loss: 0.8175 - val_accuracy: 0.8304
# Epoch 89/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1192 - accuracy: 0.9612 - val_loss: 0.9438 - val_accuracy: 0.8170
# Epoch 90/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.0778 - accuracy: 0.9742 - val_loss: 1.0061 - val_accuracy: 0.7991
# Epoch 91/100
# 71/71 [==============================] - 90s 1s/step - loss: 0.1126 - accuracy: 0.9635 - val_loss: 0.9910 - val_accuracy: 0.8125
# Epoch 92/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1266 - accuracy: 0.9630 - val_loss: 0.9585 - val_accuracy: 0.8080
# Epoch 93/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0825 - accuracy: 0.9719 - val_loss: 0.9278 - val_accuracy: 0.8259
# Epoch 94/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0851 - accuracy: 0.9701 - val_loss: 0.6651 - val_accuracy: 0.8125
# Epoch 95/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0892 - accuracy: 0.9675 - val_loss: 0.9753 - val_accuracy: 0.8125
# Epoch 96/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.1063 - accuracy: 0.9661 - val_loss: 0.8786 - val_accuracy: 0.7902
# Epoch 97/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0893 - accuracy: 0.9679 - val_loss: 0.8049 - val_accuracy: 0.8438
# Epoch 98/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0755 - accuracy: 0.9759 - val_loss: 0.9249 - val_accuracy: 0.8348
# Epoch 99/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0705 - accuracy: 0.9764 - val_loss: 0.9075 - val_accuracy: 0.8438
# Epoch 100/100
# 71/71 [==============================] - 91s 1s/step - loss: 0.0674 - accuracy: 0.9750 - val_loss: 1.1061 - val_accuracy: 0.8214

# %%
sns.set_style(style = 'whitegrid')

fig, axes = plt.subplots(1, 2, figsize=(20, 6))
graph = ['accuracy', 'loss']
title = ["Akurasi dan Validasi Akurasi", "Loss dan Validasi Loss"]

def draw_graph(i, text, title):
  axes[i].set_title(title)
  fig = sns.lineplot(ax = axes[i], x = history.epoch, y = history.history[text], marker = 'o')
  fig = sns.lineplot(ax = axes[i], x = history.epoch, y = history.history[f'val_{text}'], marker = 'o')
  axes[i].legend([text, f'val_{text}'])

def text_graph(i, text):
  for j, (x, y) in enumerate(zip(history.epoch, history.history[f'{text}'])):
    if j == 4:
      axes[i].text(x = x - 0.2, y = y - 0.009, s = round(y, 3), color = 'red') 
  for j, (x, y) in enumerate(zip(history.epoch, history.history[f'val_{text}'])):
    if j == 4:
      axes[i].text(x = x - 0.2, y = y - 0.009, s = round(y, 3), color = 'red') 

for i, (val, tit) in enumerate(zip(graph, title)):
    draw_graph(i, val, tit)
    text_graph(i, val)

# %%
# save & load model
model.save(file_dir + 'model/MobileNetV2.h5')
model = load_model(file_dir + 'model/MobileNetV2.h5')

# %%
# train evaluation
train_eval = model.evaluate(train_generator)
for name, value in zip(model.metrics_names, train_eval):
  print(name, ':', value)
print()
# Out:
# 72/72 [==============================] - 1716s 24s/step - loss: 0.0694 - accuracy: 0.9750
# loss : 0.06939752399921417
# accuracy : 0.9749560356140137

# %%
# test evaluation
test_eval = model.evaluate(test_generator)
for name, value in zip(model.metrics_names, test_eval):
  print(name, ':', value)
print()
# Out:
# 8/8 [==============================] - 3s 401ms/step - loss: 1.1188 - accuracy: 0.8167
# loss : 1.118838906288147
# accuracy : 0.8167330622673035
