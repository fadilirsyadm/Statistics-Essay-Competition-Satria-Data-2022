# %% [markdown]
# #**ResNet152V2**

# %% [markdown]
# ###📥 **Import Libraries**

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# common library
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# tensor computation
from tensorflow.random import set_seed
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import plot_model
from keras.models import Model, load_model
from keras.applications import ResNet152V2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###🔒 **Inisialisasi Bilangan Random**

# %%
def set_random(seed):
  np.random.seed(seed)
  set_seed(seed)

set_random(2022)

# %% [markdown]
# ###🪆 **Data Augmentation**

# %%
# file directory
file_dir = '/content/drive/Shareddrives/Teman Tapi Mining/Satria Data/2022/'
data_dir = 'data/Garbage classification/Garbage classification/'
dir = file_dir + data_dir

# train generator
train = ImageDataGenerator(
    horizontal_flip = True, vertical_flip = True,
    validation_split = 0.1, rescale = 1./255,
    shear_range = 0.1, zoom_range = 0.1,
    width_shift_range = 0.1, height_shift_range = 0.1
    )
train_generator = train.flow_from_directory(
    dir, target_size = (512, 384), batch_size = 32,
    class_mode = 'categorical', subset = 'training'
    )

# test generator
test = ImageDataGenerator(rescale = 1./255, validation_split = 0.1)
test_generator = test.flow_from_directory(
    dir, target_size = (512, 384), batch_size = 32,
    class_mode = 'categorical', subset = 'validation'
    )
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %% [markdown]
# ###🎯 **Modeling**

# %%
pretrained = ResNet152V2(input_shape = (512, 384, 3), include_top = False, weights = 'imagenet')
pretrained.trainable = False
layers = Flatten()(pretrained.output)
layers = Dense(64, activation = 'relu')(layers)
outputs = Dense(6, activation = 'softmax')(layers)
model = Model(inputs = [pretrained.input], outputs = [outputs])

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 7s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 384, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 518, 390, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 256, 192, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 258, 194, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 128, 96, 64)  0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 128, 96, 64)  256        ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 128, 96, 64)  0          ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 96, 64)  4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 96, 64)  256        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 128, 96, 64)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 130, 98, 64)  0          ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 96, 64)  36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 128, 96, 64)  256        ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 128, 96, 64)  0          ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 128, 96, 256  16640       ['conv2_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 128, 96, 256  16640       ['conv2_block1_2_relu[0][0]']
#                                 )
#
#  conv2_block1_out (Add)         (None, 128, 96, 256  0           ['conv2_block1_0_conv[0][0]',
#                                 )                                 'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 128, 96, 256  1024       ['conv2_block1_out[0][0]']
#  ormalization)                  )
#
#  conv2_block2_preact_relu (Acti  (None, 128, 96, 256  0          ['conv2_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 96, 64)  16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 96, 64)  256        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 128, 96, 64)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 130, 98, 64)  0          ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 96, 64)  36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 128, 96, 64)  256        ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 128, 96, 64)  0          ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 128, 96, 256  16640       ['conv2_block2_2_relu[0][0]']
#                                 )
#
#  conv2_block2_out (Add)         (None, 128, 96, 256  0           ['conv2_block1_out[0][0]',
#                                 )                                 'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 128, 96, 256  1024       ['conv2_block2_out[0][0]']
#  ormalization)                  )
#
#  conv2_block3_preact_relu (Acti  (None, 128, 96, 256  0          ['conv2_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 96, 64)  16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 96, 64)  256        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 128, 96, 64)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 130, 98, 64)  0          ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 48, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, 48, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 64, 48, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 48, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 64, 48, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 64, 48, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 64, 48, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 64, 48, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 48, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 64, 48, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 64, 48, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 64, 48, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 64, 48, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 64, 48, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv3_block5_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block5_preact_bn[0][0]']
#  vation)
#
#  conv3_block5_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block5_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block5_1_relu[0][0]']
#  g2D)
#
#  conv3_block5_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block5_2_pad[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_out (Add)         (None, 64, 48, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block5_out[0][0]']
#  ormalization)
#
#  conv3_block6_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block6_preact_bn[0][0]']
#  vation)
#
#  conv3_block6_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block6_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block6_1_relu[0][0]']
#  g2D)
#
#  conv3_block6_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block6_2_pad[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_out (Add)         (None, 64, 48, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block6_out[0][0]']
#  ormalization)
#
#  conv3_block7_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block7_preact_bn[0][0]']
#  vation)
#
#  conv3_block7_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block7_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block7_1_relu[0][0]']
#  g2D)
#
#  conv3_block7_2_conv (Conv2D)   (None, 64, 48, 128)  147456      ['conv3_block7_2_pad[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 64, 48, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_out (Add)         (None, 64, 48, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (BatchN  (None, 64, 48, 512)  2048       ['conv3_block7_out[0][0]']
#  ormalization)
#
#  conv3_block8_preact_relu (Acti  (None, 64, 48, 512)  0          ['conv3_block8_preact_bn[0][0]']
#  vation)
#
#  conv3_block8_1_conv (Conv2D)   (None, 64, 48, 128)  65536       ['conv3_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block8_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_pad (ZeroPaddin  (None, 66, 50, 128)  0          ['conv3_block8_1_relu[0][0]']
#  g2D)
#
#  conv3_block8_2_conv (Conv2D)   (None, 32, 24, 128)  147456      ['conv3_block8_2_pad[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 32, 24, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 32, 24, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 24, 512)  0          ['conv3_block7_out[0][0]']
#
#  conv3_block8_3_conv (Conv2D)   (None, 32, 24, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_out (Add)         (None, 32, 24, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 32, 24, 512)  2048       ['conv3_block8_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 32, 24, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 24, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 34, 26, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 24, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 32, 24, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 32, 24, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 32, 24, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 32, 24, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 32, 24, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 24, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 34, 26, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 24, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 32, 24, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 32, 24, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 32, 24, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 32, 24, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 24, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 34, 26, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 24, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 32, 24, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 32, 24, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 32, 24, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 32, 24, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 24, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 24, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
# ...
#  conv4_block35_2_bn (BatchNorma  (None, 32, 24, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 32, 24, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 32, 24, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_out (Add)        (None, 32, 24, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_conv[0][0]']
#
#  conv4_block36_preact_bn (Batch  (None, 32, 24, 1024  4096       ['conv4_block35_out[0][0]']
#  Normalization)                 )
#
#  conv4_block36_preact_relu (Act  (None, 32, 24, 1024  0          ['conv4_block36_preact_bn[0][0]']
#  ivation)                       )
#
#  conv4_block36_1_conv (Conv2D)  (None, 32, 24, 256)  262144      ['conv4_block36_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block36_1_bn (BatchNorma  (None, 32, 24, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 32, 24, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_pad (ZeroPaddi  (None, 34, 26, 256)  0          ['conv4_block36_1_relu[0][0]']
#  ng2D)
#
#  conv4_block36_2_conv (Conv2D)  (None, 16, 12, 256)  589824      ['conv4_block36_2_pad[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 16, 12, 256)  1024       ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 16, 12, 256)  0          ['conv4_block36_2_bn[0][0]']
#  on)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 12, 1024  0          ['conv4_block35_out[0][0]']
#                                 )
#
#  conv4_block36_3_conv (Conv2D)  (None, 16, 12, 1024  263168      ['conv4_block36_2_relu[0][0]']
#                                 )
#
#  conv4_block36_out (Add)        (None, 16, 12, 1024  0           ['max_pooling2d_2[0][0]',
#                                 )                                 'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 16, 12, 1024  4096       ['conv4_block36_out[0][0]']
#  ormalization)                  )
#
#  conv5_block1_preact_relu (Acti  (None, 16, 12, 1024  0          ['conv5_block1_preact_bn[0][0]']
#  vation)                        )
#
#  conv5_block1_1_conv (Conv2D)   (None, 16, 12, 512)  524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 16, 12, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 16, 12, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 18, 14, 512)  0          ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 16, 12, 512)  2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 16, 12, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 16, 12, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 16, 12, 2048  2099200     ['conv5_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 16, 12, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_out (Add)         (None, 16, 12, 2048  0           ['conv5_block1_0_conv[0][0]',
#                                 )                                 'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 16, 12, 2048  8192       ['conv5_block1_out[0][0]']
#  ormalization)                  )
#
#  conv5_block2_preact_relu (Acti  (None, 16, 12, 2048  0          ['conv5_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv5_block2_1_conv (Conv2D)   (None, 16, 12, 512)  1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 16, 12, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 16, 12, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 18, 14, 512)  0          ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 16, 12, 512)  2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 16, 12, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 16, 12, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 16, 12, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_out (Add)         (None, 16, 12, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 16, 12, 2048  8192       ['conv5_block2_out[0][0]']
#  ormalization)                  )
#
#  conv5_block3_preact_relu (Acti  (None, 16, 12, 2048  0          ['conv5_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv5_block3_1_conv (Conv2D)   (None, 16, 12, 512)  1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 16, 12, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 16, 12, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 18, 14, 512)  0          ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 16, 12, 512)  2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 16, 12, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 16, 12, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 16, 12, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_out (Add)         (None, 16, 12, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 16, 12, 2048  8192        ['conv5_block3_out[0][0]']
#                                 )
#
#  post_relu (Activation)         (None, 16, 12, 2048  0           ['post_bn[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 393216)       0           ['post_relu[0][0]']
#
#  dense (Dense)                  (None, 64)           25165888    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 6)            390         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 83,497,926
# Trainable params: 25,166,278
# Non-trainable params: 58,331,648
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes = True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.529046 to fit

# %%
# define parameters
batch_size = 32
num_epochs = 100

# train & test steps
step_size_train = train_generator.n//train_generator.batch_size
step_size_test = test_generator.n//test_generator.batch_size

# %%
history = model.fit(
    train_generator, epochs = num_epochs, steps_per_epoch = step_size_train,
    validation_data = test_generator, validation_steps = step_size_test
    )
# Out:
# Epoch 1/100
# 71/71 [==============================] - 1786s 25s/step - loss: 3.2516 - accuracy: 0.6056 - val_loss: 1.0545 - val_accuracy: 0.6920
# Epoch 2/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.8625 - accuracy: 0.7242 - val_loss: 1.0322 - val_accuracy: 0.7098
# Epoch 3/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.6938 - accuracy: 0.7727 - val_loss: 0.7505 - val_accuracy: 0.7991
# Epoch 4/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.6114 - accuracy: 0.8021 - val_loss: 0.6867 - val_accuracy: 0.7500
# Epoch 5/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.5883 - accuracy: 0.8155 - val_loss: 0.7921 - val_accuracy: 0.7545
# Epoch 6/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.5450 - accuracy: 0.8186 - val_loss: 0.7898 - val_accuracy: 0.7723
# Epoch 7/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.5595 - accuracy: 0.8222 - val_loss: 0.7707 - val_accuracy: 0.7723
# Epoch 8/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.4791 - accuracy: 0.8405 - val_loss: 0.6996 - val_accuracy: 0.8080
# Epoch 9/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.4294 - accuracy: 0.8583 - val_loss: 0.7572 - val_accuracy: 0.8080
# Epoch 10/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.4213 - accuracy: 0.8623 - val_loss: 0.6089 - val_accuracy: 0.8482
# Epoch 11/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.3636 - accuracy: 0.8779 - val_loss: 0.6568 - val_accuracy: 0.7902
# Epoch 12/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.4112 - accuracy: 0.8627 - val_loss: 0.6815 - val_accuracy: 0.8036
# Epoch 13/100
# 71/71 [==============================] - 114s 2s/step - loss: 0.3550 - accuracy: 0.8775 - val_loss: 0.7285 - val_accuracy: 0.8214
# Epoch 14/100
# 71/71 [==============================] - 114s 2s/step - loss: 0.3758 - accuracy: 0.8672 - val_loss: 0.6105 - val_accuracy: 0.8080
# Epoch 15/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.3299 - accuracy: 0.8971 - val_loss: 0.7909 - val_accuracy: 0.8259
# Epoch 16/100
# 71/71 [==============================] - 113s 2s/step - loss: 0.3011 - accuracy: 0.8962 - val_loss: 0.7761 - val_accuracy: 0.8482
# Epoch 17/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.2671 - accuracy: 0.9073 - val_loss: 0.7340 - val_accuracy: 0.8170
# Epoch 18/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.2454 - accuracy: 0.9242 - val_loss: 0.8728 - val_accuracy: 0.8393
# Epoch 19/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.2688 - accuracy: 0.9086 - val_loss: 0.6817 - val_accuracy: 0.8036
# Epoch 20/100
# 71/71 [==============================] - 113s 2s/step - loss: 0.2335 - accuracy: 0.9171 - val_loss: 0.5766 - val_accuracy: 0.8214
# Epoch 21/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.2352 - accuracy: 0.9180 - val_loss: 0.8005 - val_accuracy: 0.8259
# Epoch 22/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.2455 - accuracy: 0.9180 - val_loss: 0.6500 - val_accuracy: 0.8214
# Epoch 23/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1974 - accuracy: 0.9394 - val_loss: 0.9503 - val_accuracy: 0.7946
# Epoch 24/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1670 - accuracy: 0.9394 - val_loss: 0.8270 - val_accuracy: 0.8214
# Epoch 25/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.2463 - accuracy: 0.9296 - val_loss: 0.6407 - val_accuracy: 0.8036
# Epoch 26/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1904 - accuracy: 0.9349 - val_loss: 0.7216 - val_accuracy: 0.8438
# Epoch 27/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.2091 - accuracy: 0.9354 - val_loss: 0.6198 - val_accuracy: 0.8080
# Epoch 28/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1688 - accuracy: 0.9461 - val_loss: 0.4966 - val_accuracy: 0.8438
# Epoch 29/100
# 71/71 [==============================] - 113s 2s/step - loss: 0.1736 - accuracy: 0.9376 - val_loss: 0.9178 - val_accuracy: 0.8438
# Epoch 30/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1654 - accuracy: 0.9479 - val_loss: 0.7745 - val_accuracy: 0.8080
# Epoch 31/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1829 - accuracy: 0.9385 - val_loss: 0.7874 - val_accuracy: 0.8482
# Epoch 32/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.2012 - accuracy: 0.9309 - val_loss: 0.8113 - val_accuracy: 0.8348
# Epoch 33/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1376 - accuracy: 0.9528 - val_loss: 0.7237 - val_accuracy: 0.8527
# Epoch 34/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1825 - accuracy: 0.9443 - val_loss: 0.7032 - val_accuracy: 0.8259
# Epoch 35/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1536 - accuracy: 0.9479 - val_loss: 0.6699 - val_accuracy: 0.8438
# Epoch 36/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1442 - accuracy: 0.9488 - val_loss: 0.6922 - val_accuracy: 0.8438
# Epoch 37/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1113 - accuracy: 0.9586 - val_loss: 0.7470 - val_accuracy: 0.8393
# Epoch 38/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1295 - accuracy: 0.9545 - val_loss: 0.6671 - val_accuracy: 0.8482
# Epoch 39/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1208 - accuracy: 0.9554 - val_loss: 0.6706 - val_accuracy: 0.8482
# Epoch 40/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1669 - accuracy: 0.9532 - val_loss: 0.7228 - val_accuracy: 0.8393
# Epoch 41/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1554 - accuracy: 0.9492 - val_loss: 0.6062 - val_accuracy: 0.8482
# Epoch 42/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1081 - accuracy: 0.9635 - val_loss: 0.5908 - val_accuracy: 0.8571
# Epoch 43/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1551 - accuracy: 0.9465 - val_loss: 0.8329 - val_accuracy: 0.8482
# Epoch 44/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1535 - accuracy: 0.9492 - val_loss: 0.7589 - val_accuracy: 0.8259
# Epoch 45/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1333 - accuracy: 0.9514 - val_loss: 0.5169 - val_accuracy: 0.8571
# Epoch 46/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1330 - accuracy: 0.9586 - val_loss: 0.9867 - val_accuracy: 0.8214
# Epoch 47/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1856 - accuracy: 0.9443 - val_loss: 0.7387 - val_accuracy: 0.8527
# Epoch 48/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1344 - accuracy: 0.9559 - val_loss: 0.7093 - val_accuracy: 0.8259
# Epoch 49/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1291 - accuracy: 0.9563 - val_loss: 1.1787 - val_accuracy: 0.8080
# Epoch 50/100
# 71/71 [==============================] - 113s 2s/step - loss: 0.1232 - accuracy: 0.9563 - val_loss: 0.7775 - val_accuracy: 0.8304
# Epoch 51/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1154 - accuracy: 0.9612 - val_loss: 0.6377 - val_accuracy: 0.8571
# Epoch 52/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1057 - accuracy: 0.9684 - val_loss: 1.0387 - val_accuracy: 0.8482
# Epoch 53/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1320 - accuracy: 0.9630 - val_loss: 0.7998 - val_accuracy: 0.8571
# Epoch 54/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1165 - accuracy: 0.9594 - val_loss: 1.0374 - val_accuracy: 0.8304
# Epoch 55/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1204 - accuracy: 0.9594 - val_loss: 0.9019 - val_accuracy: 0.8214
# Epoch 56/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0944 - accuracy: 0.9630 - val_loss: 0.6860 - val_accuracy: 0.8438
# Epoch 57/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0802 - accuracy: 0.9693 - val_loss: 0.8768 - val_accuracy: 0.8348
# Epoch 58/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1108 - accuracy: 0.9684 - val_loss: 0.7596 - val_accuracy: 0.8616
# Epoch 59/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.0939 - accuracy: 0.9684 - val_loss: 1.2909 - val_accuracy: 0.8036
# Epoch 60/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1468 - accuracy: 0.9550 - val_loss: 1.1657 - val_accuracy: 0.8080
# Epoch 61/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1053 - accuracy: 0.9643 - val_loss: 1.3711 - val_accuracy: 0.7946
# Epoch 62/100
# 71/71 [==============================] - 113s 2s/step - loss: 0.0951 - accuracy: 0.9688 - val_loss: 1.1001 - val_accuracy: 0.8304
# Epoch 63/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0909 - accuracy: 0.9684 - val_loss: 0.7505 - val_accuracy: 0.8482
# Epoch 64/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.0633 - accuracy: 0.9746 - val_loss: 0.9430 - val_accuracy: 0.8482
# Epoch 65/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0629 - accuracy: 0.9746 - val_loss: 0.9443 - val_accuracy: 0.8348
# Epoch 66/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1019 - accuracy: 0.9675 - val_loss: 0.8824 - val_accuracy: 0.8304
# Epoch 67/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.1018 - accuracy: 0.9679 - val_loss: 0.8112 - val_accuracy: 0.8438
# Epoch 68/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.0852 - accuracy: 0.9719 - val_loss: 0.8839 - val_accuracy: 0.8661
# Epoch 69/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1086 - accuracy: 0.9684 - val_loss: 0.9061 - val_accuracy: 0.8616
# Epoch 70/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1085 - accuracy: 0.9724 - val_loss: 0.8279 - val_accuracy: 0.8393
# Epoch 71/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0943 - accuracy: 0.9679 - val_loss: 1.1171 - val_accuracy: 0.8438
# Epoch 72/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0909 - accuracy: 0.9697 - val_loss: 1.1239 - val_accuracy: 0.8304
# Epoch 73/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0736 - accuracy: 0.9737 - val_loss: 0.8494 - val_accuracy: 0.8482
# Epoch 74/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0818 - accuracy: 0.9737 - val_loss: 0.9407 - val_accuracy: 0.8482
# Epoch 75/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.1201 - accuracy: 0.9675 - val_loss: 0.9944 - val_accuracy: 0.8125
# Epoch 76/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.1142 - accuracy: 0.9661 - val_loss: 1.0628 - val_accuracy: 0.8571
# Epoch 77/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0769 - accuracy: 0.9733 - val_loss: 0.7068 - val_accuracy: 0.8661
# Epoch 78/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0955 - accuracy: 0.9697 - val_loss: 0.6758 - val_accuracy: 0.8839
# Epoch 79/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0744 - accuracy: 0.9715 - val_loss: 1.1151 - val_accuracy: 0.8482
# Epoch 80/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0834 - accuracy: 0.9724 - val_loss: 0.9631 - val_accuracy: 0.8616
# Epoch 81/100
# 71/71 [==============================] - 109s 2s/step - loss: 0.0968 - accuracy: 0.9701 - val_loss: 1.3527 - val_accuracy: 0.8214
# Epoch 82/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.1368 - accuracy: 0.9599 - val_loss: 0.8977 - val_accuracy: 0.8661
# Epoch 83/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0997 - accuracy: 0.9701 - val_loss: 1.0857 - val_accuracy: 0.8527
# Epoch 84/100
# 71/71 [==============================] - 109s 2s/step - loss: 0.0779 - accuracy: 0.9755 - val_loss: 0.9495 - val_accuracy: 0.8438
# Epoch 85/100
# 71/71 [==============================] - 109s 2s/step - loss: 0.0774 - accuracy: 0.9715 - val_loss: 0.7308 - val_accuracy: 0.8571
# Epoch 86/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0771 - accuracy: 0.9742 - val_loss: 0.8545 - val_accuracy: 0.8795
# Epoch 87/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0625 - accuracy: 0.9750 - val_loss: 0.8008 - val_accuracy: 0.8839
# Epoch 88/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0671 - accuracy: 0.9786 - val_loss: 1.1199 - val_accuracy: 0.8304
# Epoch 89/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0877 - accuracy: 0.9777 - val_loss: 0.9013 - val_accuracy: 0.8705
# Epoch 90/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0973 - accuracy: 0.9742 - val_loss: 1.0872 - val_accuracy: 0.8438
# Epoch 91/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0786 - accuracy: 0.9782 - val_loss: 0.9780 - val_accuracy: 0.8393
# Epoch 92/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0821 - accuracy: 0.9786 - val_loss: 0.9881 - val_accuracy: 0.8750
# Epoch 93/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0780 - accuracy: 0.9804 - val_loss: 0.8565 - val_accuracy: 0.8795
# Epoch 94/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0657 - accuracy: 0.9786 - val_loss: 0.9229 - val_accuracy: 0.8661
# Epoch 95/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0505 - accuracy: 0.9862 - val_loss: 0.9018 - val_accuracy: 0.8571
# Epoch 96/100
# 71/71 [==============================] - 110s 2s/step - loss: 0.0632 - accuracy: 0.9791 - val_loss: 0.8091 - val_accuracy: 0.8795
# Epoch 97/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0690 - accuracy: 0.9764 - val_loss: 0.7902 - val_accuracy: 0.8661
# Epoch 98/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.0990 - accuracy: 0.9728 - val_loss: 0.8977 - val_accuracy: 0.8884
# Epoch 99/100
# 71/71 [==============================] - 112s 2s/step - loss: 0.0855 - accuracy: 0.9764 - val_loss: 0.9612 - val_accuracy: 0.8705
# Epoch 100/100
# 71/71 [==============================] - 111s 2s/step - loss: 0.0742 - accuracy: 0.9777 - val_loss: 0.9631 - val_accuracy: 0.8795

# %%
sns.set_style(style = 'whitegrid')

fig, axes = plt.subplots(1, 2, figsize=(20, 6))
graph = ['accuracy', 'loss']
title = ["Akurasi dan Validasi Akurasi", "Loss dan Validasi Loss"]

def draw_graph(i, text, title):
  axes[i].set_title(title)
  fig = sns.lineplot(ax = axes[i], x = history.epoch, y = history.history[text], marker = 'o')
  fig = sns.lineplot(ax = axes[i], x = history.epoch, y = history.history[f'val_{text}'], marker = 'o')
  axes[i].legend([text, f'val_{text}'])

def text_graph(i, text):
  for j, (x, y) in enumerate(zip(history.epoch, history.history[f'{text}'])):
    if j == 4:
      axes[i].text(x = x - 0.2, y = y - 0.009, s = round(y, 3), color = 'red') 
  for j, (x, y) in enumerate(zip(history.epoch, history.history[f'val_{text}'])):
    if j == 4:
      axes[i].text(x = x - 0.2, y = y - 0.009, s = round(y, 3), color = 'red') 

for i, (val, tit) in enumerate(zip(graph, title)):
    draw_graph(i, val, tit)
    text_graph(i, val)

# %%
# save & load model
model.save(file_dir + 'model/ResNet152V2.h5')
model = load_model(file_dir + 'model/ResNet152V2.h5')

# %%
# train evaluation
train_eval = model.evaluate(train_generator)
for name, value in zip(model.metrics_names, train_eval):
  print(name, ':', round(value, 5))
print()
# Out:
# 72/72 [==============================] - 3136s 43s/step - loss: 0.1017 - accuracy: 0.9719
# loss : 0.10166
# accuracy : 0.97188

# %%
# test evaluation
test_eval = model.evaluate(test_generator)
for name, value in zip(model.metrics_names, test_eval):
  print(name, ':', round(value, 5))
print()
# Out:
# 8/8 [==============================] - 9s 1s/step - loss: 0.9453 - accuracy: 0.8845
# loss : 0.9453
# accuracy : 0.88446
