# %% [markdown]
# #**DenseNet201**

# %% [markdown]
# ###📥 **Import Libraries**

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# common library
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# tensor computation
from tensorflow.random import set_seed
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import plot_model
from keras.models import Model, load_model
from keras.applications import DenseNet201
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###🔒 **Inisialisasi Bilangan Random**

# %%
def set_random(seed):
  np.random.seed(seed)
  set_seed(seed)

set_random(2022)

# %% [markdown]
# ###🪆 **Data Augmentation**

# %%
# file directory
file_dir = '/content/drive/Shareddrives/Teman Tapi Mining/Satria Data/2022/'
data_dir = 'data/Garbage classification/Garbage classification/'
dir = file_dir + data_dir

# train generator
train = ImageDataGenerator(
    horizontal_flip = True, vertical_flip = True,
    validation_split = 0.1, rescale = 1./255,
    shear_range = 0.1, zoom_range = 0.1,
    width_shift_range = 0.1, height_shift_range = 0.1
    )
train_generator = train.flow_from_directory(
    dir, target_size = (512, 384), batch_size = 32,
    class_mode = 'categorical', subset = 'training'
    )

# test generator
test = ImageDataGenerator(rescale = 1./255, validation_split = 0.1)
test_generator = test.flow_from_directory(
    dir, target_size = (512, 384), batch_size = 32,
    class_mode = 'categorical', subset = 'validation'
    )
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %% [markdown]
# ###🎯 **Modeling**

# %%
pretrained = DenseNet201(input_shape = (512, 384, 3), include_top = False, weights = 'imagenet')
pretrained.trainable = False
layers = Flatten()(pretrained.output)
layers = Dense(64, activation = 'relu')(layers)
outputs = Dense(6, activation = 'softmax')(layers)
model = Model(inputs = [pretrained.input], outputs = [outputs])

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 2s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 384, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 518, 390, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 256, 192, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 256, 192, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 256, 192, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 258, 194, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 128, 96, 64)  0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 96, 64)  256        ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 128, 96, 64)  0          ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 96, 128  8192        ['conv2_block1_0_relu[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 96, 32)  36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 128, 96, 96)  0          ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 128, 96, 96)  384        ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 128, 96, 96)  0          ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 96, 128  12288       ['conv2_block2_0_relu[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 96, 32)  36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 128, 96, 128  0          ['conv2_block1_concat[0][0]',
#  te)                            )                                 'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block2_concat[0][0]']
#  ization)                       )
#
#  conv2_block3_0_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block3_0_bn[0][0]']
#  n)                             )
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 96, 128  16384       ['conv2_block3_0_relu[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 96, 32)  36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 128, 96, 160  0          ['conv2_block2_concat[0][0]',
#  te)                            )                                 'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 128, 96, 160  640        ['conv2_block3_concat[0][0]']
#  ization)                       )
#
#  conv2_block4_0_relu (Activatio  (None, 128, 96, 160  0          ['conv2_block4_0_bn[0][0]']
#  n)                             )
#
#  conv2_block4_1_conv (Conv2D)   (None, 128, 96, 128  20480       ['conv2_block4_0_relu[0][0]']
#                                 )
#
#  conv2_block4_1_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block4_1_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block4_1_bn[0][0]']
#  n)                             )
#
#  conv2_block4_2_conv (Conv2D)   (None, 128, 96, 32)  36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 128, 96, 192  0          ['conv2_block3_concat[0][0]',
#  te)                            )                                 'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 128, 96, 192  768        ['conv2_block4_concat[0][0]']
#  ization)                       )
#
#  conv2_block5_0_relu (Activatio  (None, 128, 96, 192  0          ['conv2_block5_0_bn[0][0]']
#  n)                             )
#
#  conv2_block5_1_conv (Conv2D)   (None, 128, 96, 128  24576       ['conv2_block5_0_relu[0][0]']
#                                 )
#
#  conv2_block5_1_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block5_1_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block5_1_bn[0][0]']
#  n)                             )
#
#  conv2_block5_2_conv (Conv2D)   (None, 128, 96, 32)  36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 128, 96, 224  0          ['conv2_block4_concat[0][0]',
#  te)                            )                                 'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 128, 96, 224  896        ['conv2_block5_concat[0][0]']
#  ization)                       )
#
#  conv2_block6_0_relu (Activatio  (None, 128, 96, 224  0          ['conv2_block6_0_bn[0][0]']
#  n)                             )
#
#  conv2_block6_1_conv (Conv2D)   (None, 128, 96, 128  28672       ['conv2_block6_0_relu[0][0]']
#                                 )
#
#  conv2_block6_1_bn (BatchNormal  (None, 128, 96, 128  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block6_1_relu (Activatio  (None, 128, 96, 128  0          ['conv2_block6_1_bn[0][0]']
#  n)                             )
#
#  conv2_block6_2_conv (Conv2D)   (None, 128, 96, 32)  36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 128, 96, 256  0          ['conv2_block5_concat[0][0]',
#  te)                            )                                 'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 128, 96, 256  1024        ['conv2_block6_concat[0][0]']
#                                 )
#
#  pool2_relu (Activation)        (None, 128, 96, 256  0           ['pool2_bn[0][0]']
#                                 )
#
#  pool2_conv (Conv2D)            (None, 128, 96, 128  32768       ['pool2_relu[0][0]']
#                                 )
#
#  pool2_pool (AveragePooling2D)  (None, 64, 48, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 48, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 48, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 64, 48, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 64, 48, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 64, 48, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 48, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 64, 48, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 64, 48, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 64, 48, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 48, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 64, 48, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 64, 48, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 64, 48, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 48, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 64, 48, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 64, 48, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 64, 48, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 64, 48, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 64, 48, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 64, 48, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 64, 48, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 64, 48, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 64, 48, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 64, 48, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 64, 48, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 64, 48, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 64, 48, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 64, 48, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 64, 48, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 64, 48, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 64, 48, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 64, 48, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 64, 48, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 64, 48, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 64, 48, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 64, 48, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 64, 48, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 64, 48, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 64, 48, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 64, 48, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 64, 48, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 64, 48, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 64, 48, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 64, 48, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 64, 48, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 64, 48, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 64, 48, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 64, 48, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 64, 48, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 64, 48, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 64, 48, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 64, 48, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 64, 48, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 64, 48, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 64, 48, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 64, 48, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 64, 48, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 64, 48, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 64, 48, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 64, 48, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 64, 48, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 64, 48, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 32, 24, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 24, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 32, 24, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 24, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 24, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 24, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 24, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 32, 24, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 32, 24, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 32, 24, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 24, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 24, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 24, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 24, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 32, 24, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 32, 24, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 32, 24, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 24, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 24, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 24, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 24, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 32, 24, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 32, 24, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 32, 24, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 24, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 24, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 24, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 24, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 32, 24, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 32, 24, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 32, 24, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 24, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 24, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 24, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 24, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 32, 24, 416)  0          ['conv4_block4_concat[0][0]',
# ...
#  conv5_block25_1_conv (Conv2D)  (None, 16, 12, 128)  212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 16, 12, 1696  0          ['conv5_block24_concat[0][0]',
#  ate)                           )                                 'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 16, 12, 1696  6784       ['conv5_block25_concat[0][0]']
#  lization)                      )
#
#  conv5_block26_0_relu (Activati  (None, 16, 12, 1696  0          ['conv5_block26_0_bn[0][0]']
#  on)                            )
#
#  conv5_block26_1_conv (Conv2D)  (None, 16, 12, 128)  217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 16, 12, 1728  0          ['conv5_block25_concat[0][0]',
#  ate)                           )                                 'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 16, 12, 1728  6912       ['conv5_block26_concat[0][0]']
#  lization)                      )
#
#  conv5_block27_0_relu (Activati  (None, 16, 12, 1728  0          ['conv5_block27_0_bn[0][0]']
#  on)                            )
#
#  conv5_block27_1_conv (Conv2D)  (None, 16, 12, 128)  221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 16, 12, 1760  0          ['conv5_block26_concat[0][0]',
#  ate)                           )                                 'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 16, 12, 1760  7040       ['conv5_block27_concat[0][0]']
#  lization)                      )
#
#  conv5_block28_0_relu (Activati  (None, 16, 12, 1760  0          ['conv5_block28_0_bn[0][0]']
#  on)                            )
#
#  conv5_block28_1_conv (Conv2D)  (None, 16, 12, 128)  225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 16, 12, 1792  0          ['conv5_block27_concat[0][0]',
#  ate)                           )                                 'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 16, 12, 1792  7168       ['conv5_block28_concat[0][0]']
#  lization)                      )
#
#  conv5_block29_0_relu (Activati  (None, 16, 12, 1792  0          ['conv5_block29_0_bn[0][0]']
#  on)                            )
#
#  conv5_block29_1_conv (Conv2D)  (None, 16, 12, 128)  229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 16, 12, 1824  0          ['conv5_block28_concat[0][0]',
#  ate)                           )                                 'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 16, 12, 1824  7296       ['conv5_block29_concat[0][0]']
#  lization)                      )
#
#  conv5_block30_0_relu (Activati  (None, 16, 12, 1824  0          ['conv5_block30_0_bn[0][0]']
#  on)                            )
#
#  conv5_block30_1_conv (Conv2D)  (None, 16, 12, 128)  233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 16, 12, 1856  0          ['conv5_block29_concat[0][0]',
#  ate)                           )                                 'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 16, 12, 1856  7424       ['conv5_block30_concat[0][0]']
#  lization)                      )
#
#  conv5_block31_0_relu (Activati  (None, 16, 12, 1856  0          ['conv5_block31_0_bn[0][0]']
#  on)                            )
#
#  conv5_block31_1_conv (Conv2D)  (None, 16, 12, 128)  237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 16, 12, 1888  0          ['conv5_block30_concat[0][0]',
#  ate)                           )                                 'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 16, 12, 1888  7552       ['conv5_block31_concat[0][0]']
#  lization)                      )
#
#  conv5_block32_0_relu (Activati  (None, 16, 12, 1888  0          ['conv5_block32_0_bn[0][0]']
#  on)                            )
#
#  conv5_block32_1_conv (Conv2D)  (None, 16, 12, 128)  241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 16, 12, 128)  512        ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 16, 12, 128)  0          ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 16, 12, 32)   36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 16, 12, 1920  0          ['conv5_block31_concat[0][0]',
#  ate)                           )                                 'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 16, 12, 1920  7680        ['conv5_block32_concat[0][0]']
#                                 )
#
#  relu (Activation)              (None, 16, 12, 1920  0           ['bn[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 368640)       0           ['relu[0][0]']
#
#  dense (Dense)                  (None, 64)           23593024    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 6)            390         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 41,915,398
# Trainable params: 23,593,414
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes = True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.417223 to fit

# %%
# define parameters
batch_size = 32
num_epochs = 100

# train & test steps
step_size_train = train_generator.n//train_generator.batch_size
step_size_test = test_generator.n//test_generator.batch_size

# %%
history = model.fit(
    train_generator, epochs = num_epochs, steps_per_epoch = step_size_train,
    validation_data = test_generator, validation_steps = step_size_test
    )
# Out:
# Epoch 1/100
# 71/71 [==============================] - 1574s 22s/step - loss: 3.8757 - accuracy: 0.4118 - val_loss: 1.3829 - val_accuracy: 0.4643
# Epoch 2/100
# 71/71 [==============================] - 102s 1s/step - loss: 1.2569 - accuracy: 0.5143 - val_loss: 1.1400 - val_accuracy: 0.5670
# Epoch 3/100
# 71/71 [==============================] - 103s 1s/step - loss: 1.0075 - accuracy: 0.5406 - val_loss: 0.8796 - val_accuracy: 0.5625
# Epoch 4/100
# 71/71 [==============================] - 103s 1s/step - loss: 0.9009 - accuracy: 0.5660 - val_loss: 1.1079 - val_accuracy: 0.5804
# Epoch 5/100
# 71/71 [==============================] - 102s 1s/step - loss: 0.8886 - accuracy: 0.5798 - val_loss: 0.9121 - val_accuracy: 0.6339
# Epoch 6/100
# 71/71 [==============================] - 102s 1s/step - loss: 0.8121 - accuracy: 0.6257 - val_loss: 0.8204 - val_accuracy: 0.6071
# Epoch 7/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.8221 - accuracy: 0.6248 - val_loss: 0.8251 - val_accuracy: 0.6875
# Epoch 8/100
# 71/71 [==============================] - 102s 1s/step - loss: 0.8084 - accuracy: 0.6292 - val_loss: 0.8089 - val_accuracy: 0.6696
# Epoch 9/100
# 71/71 [==============================] - 103s 1s/step - loss: 0.7800 - accuracy: 0.6520 - val_loss: 0.9426 - val_accuracy: 0.6250
# Epoch 10/100
# 71/71 [==============================] - 102s 1s/step - loss: 0.7646 - accuracy: 0.6631 - val_loss: 0.7537 - val_accuracy: 0.6830
# Epoch 11/100
# 71/71 [==============================] - 102s 1s/step - loss: 0.7127 - accuracy: 0.6720 - val_loss: 0.9052 - val_accuracy: 0.6741
# Epoch 12/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.7438 - accuracy: 0.6680 - val_loss: 1.0224 - val_accuracy: 0.6339
# Epoch 13/100
# 71/71 [==============================] - 102s 1s/step - loss: 0.7096 - accuracy: 0.6894 - val_loss: 0.8179 - val_accuracy: 0.6964
# Epoch 14/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.7029 - accuracy: 0.6923 - val_loss: 0.7433 - val_accuracy: 0.7098
# Epoch 15/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.6728 - accuracy: 0.7001 - val_loss: 0.7470 - val_accuracy: 0.7188
# Epoch 16/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.6465 - accuracy: 0.7237 - val_loss: 0.8984 - val_accuracy: 0.6741
# Epoch 17/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.6115 - accuracy: 0.7571 - val_loss: 0.7665 - val_accuracy: 0.7277
# Epoch 18/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.6073 - accuracy: 0.7629 - val_loss: 0.7529 - val_accuracy: 0.7411
# Epoch 19/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.6016 - accuracy: 0.7750 - val_loss: 0.9264 - val_accuracy: 0.7098
# Epoch 20/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.5809 - accuracy: 0.7830 - val_loss: 0.8812 - val_accuracy: 0.7098
# Epoch 21/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.5691 - accuracy: 0.7901 - val_loss: 0.8272 - val_accuracy: 0.6964
# Epoch 22/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.5569 - accuracy: 0.7968 - val_loss: 0.7238 - val_accuracy: 0.7188
# Epoch 23/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.5412 - accuracy: 0.8119 - val_loss: 0.9758 - val_accuracy: 0.7098
# Epoch 24/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.4687 - accuracy: 0.8445 - val_loss: 0.7526 - val_accuracy: 0.7500
# Epoch 25/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.4847 - accuracy: 0.8396 - val_loss: 0.9214 - val_accuracy: 0.7634
# Epoch 26/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.4369 - accuracy: 0.8547 - val_loss: 0.7101 - val_accuracy: 0.7545
# Epoch 27/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.4309 - accuracy: 0.8632 - val_loss: 0.6913 - val_accuracy: 0.7857
# Epoch 28/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.4145 - accuracy: 0.8592 - val_loss: 0.8152 - val_accuracy: 0.7545
# Epoch 29/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.4128 - accuracy: 0.8596 - val_loss: 0.6749 - val_accuracy: 0.7589
# Epoch 30/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.3988 - accuracy: 0.8690 - val_loss: 0.7155 - val_accuracy: 0.7857
# Epoch 31/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.3631 - accuracy: 0.8810 - val_loss: 0.7057 - val_accuracy: 0.7812
# Epoch 32/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.3678 - accuracy: 0.8806 - val_loss: 0.7939 - val_accuracy: 0.7634
# Epoch 33/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.4060 - accuracy: 0.8712 - val_loss: 0.9765 - val_accuracy: 0.7411
# Epoch 34/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.3805 - accuracy: 0.8824 - val_loss: 0.6156 - val_accuracy: 0.7902
# Epoch 35/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.3064 - accuracy: 0.9042 - val_loss: 0.7592 - val_accuracy: 0.7679
# Epoch 36/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.3178 - accuracy: 0.9015 - val_loss: 0.6437 - val_accuracy: 0.8036
# Epoch 37/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.3107 - accuracy: 0.9011 - val_loss: 1.0775 - val_accuracy: 0.7277
# Epoch 38/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.3144 - accuracy: 0.9011 - val_loss: 0.7701 - val_accuracy: 0.7634
# Epoch 39/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.3031 - accuracy: 0.9064 - val_loss: 0.7466 - val_accuracy: 0.7768
# Epoch 40/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.2855 - accuracy: 0.9113 - val_loss: 0.8554 - val_accuracy: 0.7545
# Epoch 41/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2969 - accuracy: 0.9024 - val_loss: 0.6151 - val_accuracy: 0.7902
# Epoch 42/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2757 - accuracy: 0.9144 - val_loss: 0.7786 - val_accuracy: 0.7946
# Epoch 43/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.2761 - accuracy: 0.9127 - val_loss: 0.6867 - val_accuracy: 0.8304
# Epoch 44/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2614 - accuracy: 0.9189 - val_loss: 0.6907 - val_accuracy: 0.8036
# Epoch 45/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2552 - accuracy: 0.9153 - val_loss: 0.6457 - val_accuracy: 0.8036
# Epoch 46/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2630 - accuracy: 0.9251 - val_loss: 0.8528 - val_accuracy: 0.7679
# Epoch 47/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2459 - accuracy: 0.9274 - val_loss: 0.7209 - val_accuracy: 0.8036
# Epoch 48/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2338 - accuracy: 0.9234 - val_loss: 0.7382 - val_accuracy: 0.7902
# Epoch 49/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2341 - accuracy: 0.9309 - val_loss: 0.6794 - val_accuracy: 0.8170
# Epoch 50/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2178 - accuracy: 0.9336 - val_loss: 0.8883 - val_accuracy: 0.7723
# Epoch 51/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2276 - accuracy: 0.9291 - val_loss: 0.8659 - val_accuracy: 0.8170
# Epoch 52/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2490 - accuracy: 0.9225 - val_loss: 0.7748 - val_accuracy: 0.7857
# Epoch 53/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2260 - accuracy: 0.9332 - val_loss: 1.0712 - val_accuracy: 0.7679
# Epoch 54/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2204 - accuracy: 0.9336 - val_loss: 0.9088 - val_accuracy: 0.7946
# Epoch 55/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2310 - accuracy: 0.9381 - val_loss: 0.8570 - val_accuracy: 0.7812
# Epoch 56/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2099 - accuracy: 0.9345 - val_loss: 0.8958 - val_accuracy: 0.7812
# Epoch 57/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1982 - accuracy: 0.9340 - val_loss: 0.9502 - val_accuracy: 0.8036
# Epoch 58/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2303 - accuracy: 0.9363 - val_loss: 0.7191 - val_accuracy: 0.8214
# Epoch 59/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.2284 - accuracy: 0.9291 - val_loss: 0.8108 - val_accuracy: 0.8125
# Epoch 60/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1856 - accuracy: 0.9407 - val_loss: 1.0951 - val_accuracy: 0.7857
# Epoch 61/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.2086 - accuracy: 0.9376 - val_loss: 0.7399 - val_accuracy: 0.7679
# Epoch 62/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.3010 - accuracy: 0.9086 - val_loss: 0.7210 - val_accuracy: 0.8125
# Epoch 63/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1927 - accuracy: 0.9412 - val_loss: 0.9241 - val_accuracy: 0.7768
# Epoch 64/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.1930 - accuracy: 0.9389 - val_loss: 0.6096 - val_accuracy: 0.8259
# Epoch 65/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1736 - accuracy: 0.9416 - val_loss: 0.7533 - val_accuracy: 0.8304
# Epoch 66/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1713 - accuracy: 0.9425 - val_loss: 0.7752 - val_accuracy: 0.8036
# Epoch 67/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1665 - accuracy: 0.9514 - val_loss: 0.6817 - val_accuracy: 0.8304
# Epoch 68/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1580 - accuracy: 0.9514 - val_loss: 0.8303 - val_accuracy: 0.8080
# Epoch 69/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1783 - accuracy: 0.9514 - val_loss: 0.6443 - val_accuracy: 0.8527
# Epoch 70/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1813 - accuracy: 0.9492 - val_loss: 0.8857 - val_accuracy: 0.8170
# Epoch 71/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1417 - accuracy: 0.9599 - val_loss: 0.8837 - val_accuracy: 0.8170
# Epoch 72/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1634 - accuracy: 0.9514 - val_loss: 0.8541 - val_accuracy: 0.8036
# Epoch 73/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1589 - accuracy: 0.9488 - val_loss: 0.8274 - val_accuracy: 0.8259
# Epoch 74/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1534 - accuracy: 0.9545 - val_loss: 0.9875 - val_accuracy: 0.7723
# Epoch 75/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1419 - accuracy: 0.9572 - val_loss: 0.7517 - val_accuracy: 0.8393
# Epoch 76/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1578 - accuracy: 0.9510 - val_loss: 0.8968 - val_accuracy: 0.8393
# Epoch 77/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1569 - accuracy: 0.9523 - val_loss: 0.7139 - val_accuracy: 0.7991
# Epoch 78/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1301 - accuracy: 0.9652 - val_loss: 0.5968 - val_accuracy: 0.8393
# Epoch 79/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1506 - accuracy: 0.9563 - val_loss: 1.0358 - val_accuracy: 0.7991
# Epoch 80/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1450 - accuracy: 0.9603 - val_loss: 0.9401 - val_accuracy: 0.8170
# Epoch 81/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1375 - accuracy: 0.9635 - val_loss: 0.9651 - val_accuracy: 0.8036
# Epoch 82/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1454 - accuracy: 0.9554 - val_loss: 0.9014 - val_accuracy: 0.8438
# Epoch 83/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1235 - accuracy: 0.9617 - val_loss: 0.8209 - val_accuracy: 0.8348
# Epoch 84/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1443 - accuracy: 0.9594 - val_loss: 0.9987 - val_accuracy: 0.8170
# Epoch 85/100
# 71/71 [==============================] - 101s 1s/step - loss: 0.1541 - accuracy: 0.9516 - val_loss: 0.8187 - val_accuracy: 0.8036
# Epoch 86/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1451 - accuracy: 0.9554 - val_loss: 1.1051 - val_accuracy: 0.8036
# Epoch 87/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1400 - accuracy: 0.9608 - val_loss: 0.7023 - val_accuracy: 0.8438
# Epoch 88/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1255 - accuracy: 0.9643 - val_loss: 0.8441 - val_accuracy: 0.8304
# Epoch 89/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1418 - accuracy: 0.9577 - val_loss: 0.8770 - val_accuracy: 0.8080
# Epoch 90/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1349 - accuracy: 0.9608 - val_loss: 1.0718 - val_accuracy: 0.8125
# Epoch 91/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1218 - accuracy: 0.9652 - val_loss: 0.7902 - val_accuracy: 0.8214
# Epoch 92/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1126 - accuracy: 0.9679 - val_loss: 0.8033 - val_accuracy: 0.8304
# Epoch 93/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1161 - accuracy: 0.9675 - val_loss: 0.6111 - val_accuracy: 0.8482
# Epoch 94/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1198 - accuracy: 0.9603 - val_loss: 0.8591 - val_accuracy: 0.8482
# Epoch 95/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1165 - accuracy: 0.9652 - val_loss: 0.9413 - val_accuracy: 0.8125
# Epoch 96/100
# 71/71 [==============================] - 98s 1s/step - loss: 0.1161 - accuracy: 0.9626 - val_loss: 0.8152 - val_accuracy: 0.8348
# Epoch 97/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1174 - accuracy: 0.9679 - val_loss: 1.0429 - val_accuracy: 0.8304
# Epoch 98/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1659 - accuracy: 0.9479 - val_loss: 1.0767 - val_accuracy: 0.7946
# Epoch 99/100
# 71/71 [==============================] - 99s 1s/step - loss: 0.1444 - accuracy: 0.9532 - val_loss: 0.7367 - val_accuracy: 0.8304
# Epoch 100/100
# 71/71 [==============================] - 100s 1s/step - loss: 0.1034 - accuracy: 0.9701 - val_loss: 0.9914 - val_accuracy: 0.8036

# %%
sns.set_style(style = 'whitegrid')

fig, axes = plt.subplots(1, 2, figsize=(20, 6))
graph = ['accuracy', 'loss']
title = ["Akurasi dan Validasi Akurasi", "Loss dan Validasi Loss"]

def draw_graph(i, text, title):
  axes[i].set_title(title)
  fig = sns.lineplot(ax = axes[i], x = history.epoch, y = history.history[text], marker = 'o')
  fig = sns.lineplot(ax = axes[i], x = history.epoch, y = history.history[f'val_{text}'], marker = 'o')
  axes[i].legend([text, f'val_{text}'])

def text_graph(i, text):
  for j, (x, y) in enumerate(zip(history.epoch, history.history[f'{text}'])):
    if j == 4:
      axes[i].text(x = x - 0.2, y = y - 0.009, s = round(y, 3), color = 'red') 
  for j, (x, y) in enumerate(zip(history.epoch, history.history[f'val_{text}'])):
    if j == 4:
      axes[i].text(x = x - 0.2, y = y - 0.009, s = round(y, 3), color = 'red') 

for i, (val, tit) in enumerate(zip(graph, title)):
    draw_graph(i, val, tit)
    text_graph(i, val)

# %%
# save & load model
model.save(file_dir + 'model/DenseNet201.h5')
model = load_model(file_dir + 'model/DenseNet201.h5')

# %%
# train evaluation
train_eval = model.evaluate(train_generator)
for name, value in zip(model.metrics_names, train_eval):
  print(name, ':', round(value, 5))
print()
# Out:
# 72/72 [==============================] - 1991s 28s/step - loss: 0.1141 - accuracy: 0.9627
# loss : 0.11411
# accuracy : 0.96265

# %%
# test evaluation
test_eval = model.evaluate(test_generator)
for name, value in zip(model.metrics_names, test_eval):
  print(name, ':', round(value, 5))
print()
# Out:
# 8/8 [==============================] - 213s 27s/step - loss: 0.9153 - accuracy: 0.8167
# loss : 0.91528
# accuracy : 0.81673
